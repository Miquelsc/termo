# %%
Tmax=15; Tmin=5; w=2*pi/24; k0=0.1; T0=22; Tf=20
var('k'); var('t'); var('a')
Te(t)=(Tmin+Tmax)/2+(Tmax-Tmin)*sin(w*t+pi)/2
T=function('T')(t)
eq=diff(T(t),t)==-k*(T(t)-Te(t)); ics=[0,T0]
sol=desolve(eq,[T(t),t],ics)
eq2=sol(24)==Tf
K=find_root(eq2,0,0.01)
eq3=k0/(1-a)==K
a=solve(eq3,a)[0].rhs().n()
# Out:
# -12.1697176048043

# %%
# Out:
# Graphics object consisting of 100 graphics primitives

# %%
eq2=sol(24)==20
K=find_root(eq2,0,0.01)
K
# Out:
# 0.007593177241972151

# %%
var('a')
eq3=k0/(1-a)==K
solve(eq3,a)[0].rhs().n()
# Out:
# -12.1697176048043
